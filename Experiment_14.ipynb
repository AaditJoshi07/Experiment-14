# %% [markdown]
# EXPERIMENT - 14
#
# Data Binning and Data Formatting using Phyton
#
# Name:Aadit Joshi
#
# PRN: 25070123173

# %%
import pandas as pd
import numpy as np

data = {
    'Product': ['Laptop', 'Mobile', 'Tablet', 'Headphones', 'Smartwatch', 'Camera'],
    'Price': [55000, 20000, 30000, 2000, 8000, 45000],
    'Units_Sold': [25, 60, 35, 80, 50, 15]
}

df=pd.DataFrame(data)
print(df)
# Out:
#       Product  Price  Units_Sold
# 0      Laptop  55000          25
# 1      Mobile  20000          60
# 2      Tablet  30000          35
# 3  Headphones   2000          80
# 4  Smartwatch   8000          50
# 5      Camera  45000          15

# %%
#Data Binning
bins1= [0, 10000,30000,60000]
labels1=['LOW','MEDIUM','HIGH']
df['Price_Category'] = pd.cut(df['Price'],bins=bins1,labels=labels1)
print(df)
# Out:
#       Product  Price  Units_Sold Price_Category
# 0      Laptop  55000          25           HIGH
# 1      Mobile  20000          60         MEDIUM
# 2      Tablet  30000          35         MEDIUM
# 3  Headphones   2000          80            LOW
# 4  Smartwatch   8000          50            LOW
# 5      Camera  45000          15           HIGH

# %%
bins2=[0,30,60,100]
labels2=['LOW','MEDIUM','HIGH']
df['Sales_Category']=pd.cut(df['Units_Sold'],bins=bins2,labels=labels2)
print(df)
# Out:
#       Product  Price  Units_Sold Price_Category Sales_Category
# 0      Laptop  55000          25           HIGH            LOW
# 1      Mobile  20000          60         MEDIUM         MEDIUM
# 2      Tablet  30000          35         MEDIUM         MEDIUM
# 3  Headphones   2000          80            LOW           HIGH
# 4  Smartwatch   8000          50            LOW         MEDIUM
# 5      Camera  45000          15           HIGH            LOW

# %%
print(df.dtypes)
df['Units_Sold']=df['Units_Sold'].astype(float)

print(df.dtypes)
# Out:
# Product             object
# Price                int64
# Units_Sold         float64
# Price_Category    category
# Sales_Category    category
# dtype: object
# Product             object
# Price                int64
# Units_Sold         float64
# Price_Category    category
# Sales_Category    category
# dtype: object

# %%
#Convert text to uppercase
df['Product'] = df['Product'].str.upper()

print(df)
# Out:
#       Product  Price  Units_Sold Price_Category Sales_Category
# 0      LAPTOP  55000        25.0           HIGH            LOW
# 1      MOBILE  20000        60.0         MEDIUM         MEDIUM
# 2      TABLET  30000        35.0         MEDIUM         MEDIUM
# 3  HEADPHONES   2000        80.0            LOW           HIGH
# 4  SMARTWATCH   8000        50.0            LOW         MEDIUM
# 5      CAMERA  45000        15.0           HIGH            LOW

# %%
#Rounding Values
df['Price'] = df['Price'].round(2)
print(df)
# Out:
#       Product  Price  Units_Sold Price_Category Sales_Category
# 0      LAPTOP  55000        25.0           HIGH            LOW
# 1      MOBILE  20000        60.0         MEDIUM         MEDIUM
# 2      TABLET  30000        35.0         MEDIUM         MEDIUM
# 3  HEADPHONES   2000        80.0            LOW           HIGH
# 4  SMARTWATCH   8000        50.0            LOW         MEDIUM
# 5      CAMERA  45000        15.0           HIGH            LOW

# %%
#Additional operations
#Sort Data
sorted_df=df.sort_values(by='Price')
print(sorted_df)
# Out:
#       Product  Price  Units_Sold Price_Category Sales_Category
# 3  HEADPHONES   2000        80.0            LOW           HIGH
# 4  SMARTWATCH   8000        50.0            LOW         MEDIUM
# 1      MOBILE  20000        60.0         MEDIUM         MEDIUM
# 2      TABLET  30000        35.0         MEDIUM         MEDIUM
# 5      CAMERA  45000        15.0           HIGH            LOW
# 0      LAPTOP  55000        25.0           HIGH            LOW

# %%
#Additional operations
#Sort Data
sorted_df=df.sort_values(by='Price',ascending=False)
print(sorted_df)
# Out:
#       Product  Price  Units_Sold Price_Category Sales_Category
# 0      LAPTOP  55000        25.0           HIGH            LOW
# 5      CAMERA  45000        15.0           HIGH            LOW
# 2      TABLET  30000        35.0         MEDIUM         MEDIUM
# 1      MOBILE  20000        60.0         MEDIUM         MEDIUM
# 4  SMARTWATCH   8000        50.0            LOW         MEDIUM
# 3  HEADPHONES   2000        80.0            LOW           HIGH

# %%
#Display Unique Values
unique_products=df['Price_Category'].unique()
print(unique_products)
# Out:
# ['HIGH', 'MEDIUM', 'LOW']
# Categories (3, object): ['LOW' < 'MEDIUM' < 'HIGH']

# %%
import pandas as pd
import numpy as np

data = {
'Order_ID':['O1','O2','O3','O4','O5','O6','O7','O8'],
'Order_Value':[250,450,120,600,300,150,500,220],
'Delivery_Time':[30,45,25,60,35,20,50,28],
'Distance_km':[5,8,3,10,6,2,9,4]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Order_ID  Order_Value  Delivery_Time  Distance_km
# 0       O1          250             30            5
# 1       O2          450             45            8
# 2       O3          120             25            3
# 3       O4          600             60           10
# 4       O5          300             35            6
# 5       O6          150             20            2
# 6       O7          500             50            9
# 7       O8          220             28            4

# %%
#Binning Order Value
bins = [0,200,400,700]
labels1 = ['LOW order','MEDIUM order','HIGH order']
df['Order_Value_Category'] = pd.cut(df['Order_Value'],bins=bins1,labels=labels1)
print(df)
# Out:
#   Order_ID  Order_Value  Delivery_Time  Distance_km Order_Value_Category
# 0       O1          250             30            5            LOW order
# 1       O2          450             45            8            LOW order
# 2       O3          120             25            3            LOW order
# 3       O4          600             60           10            LOW order
# 4       O5          300             35            6            LOW order
# 5       O6          150             20            2            LOW order
# 6       O7          500             50            9            LOW order
# 7       O8          220             28            4            LOW order

# %%
#Count of categories
print(df['Order_Value_Category'].value_counts())
df
# Out:
# Order_Value_Category
# LOW order       8
# MEDIUM order    0
# HIGH order      0
# Name: count, dtype: int64
#   Order_ID  Order_Value  Delivery_Time  Distance_km Order_Value_Category
# 0       O1          250             30            5            LOW order
# 1       O2          450             45            8            LOW order
# 2       O3          120             25            3            LOW order
# 3       O4          600             60           10            LOW order
# 4       O5          300             35            6            LOW order
# 5       O6          150             20            2            LOW order
# 6       O7          500             50            9            LOW order
# 7       O8          220             28            4            LOW order

# %%
#Data Normalization
import pandas as pd
df = pd.read_csv('/content/amazon_products_dataset_Expt-14.csv')
print(df)
# Out:
#    Product_ID                 Product_Name  Price  Rating  Reviews  Units_Sold
# 0        P101               Wireless Mouse    799     4.3     1520         350
# 1        P102            Bluetooth Speaker   1499     4.5      980         220
# 2        P103                 USB Keyboard    699     4.1      870         180
# 3        P104               Gaming Headset   2499     4.6     2100         410
# 4        P105                   Smartwatch   3999     4.4     3050         520
# 5        P106                   Power Bank   1199     4.2     1750         390
# 6        P107                 Laptop Stand    899     4.0      620         140
# 7        P108                       Webcam   1899     4.3     1120         260
# 8        P109                 Portable SSD   5499     4.7     1850         330
# 9        P110             Wireless Charger    999     4.2      760         190
# 10       P111  Noise Cancelling Headphones   7999     4.6     4200         610
# ...

# %%
import pandas as pd

#Turning categorical varibales into quantitative variables

df = pd.read_csv('/content/Student-Dataset (1).csv')
print (df)
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary
# 0                     92           Placed  450000
# 1                     85       Not Placed       0
# 2                     96           Placed  550000
# 3                     78       Not Placed       0
# 4                     88           Placed  480000
# ...
